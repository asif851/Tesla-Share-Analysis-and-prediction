# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("dataset/tesla.csv")
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.shape
# Out:
# (1692, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.214999    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.corr()
# Out:
#                Open      High       Low     Close    Volume  Adj Close
# Open       1.000000  0.999623  0.999605  0.999233  0.407515   0.999233
# High       0.999623  1.000000  0.999521  0.999691  0.416466   0.999691
# Low        0.999605  0.999521  1.000000  0.999656  0.397615   0.999656
# Close      0.999233  0.999691  0.999656  1.000000  0.406907   1.000000
# Volume     0.407515  0.416466  0.397615  0.406907  1.000000   0.406907
# Adj Close  0.999233  0.999691  0.999656  1.000000  0.406907   1.000000

# %%
#adding column

df['Year']=df["Date"].apply(lambda x:x.split('/')[2])
df['Month']=df["Date"].apply(lambda x:x.split('/')[0])
df['Day']=df["Date"].apply(lambda x:x.split('/')[1])

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001
#
#    Year Month Day
# 0  2010     6  29
# 1  2010     6  30
# 2  2010     7   1
# 3  2010     7   2
# 4  2010     7   6

# %%
df['Date']=pd.to_datetime(df["Date"])

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001
#
#    Year Month Day
# 0  2010     6  29
# 1  2010     6  30
# 2  2010     7   1
# 3  2010     7   2
# 4  2010     7   6

# %%
#droping 2010 and 2017 raws.because these year doesn't have  every month's value

df.drop(df[df["Year"]=='2010'].index,inplace=True)
df.drop(df[df["Year"]=='2017'].index,inplace=True)

# %%
df.head()
# Out:
#           Date   Open       High        Low      Close   Volume  Adj Close  \
# 130 2011-01-03  26.84  27.000000  25.900000  26.620001  1283000  26.620001
# 131 2011-01-04  26.66  26.950001  26.020000  26.670000  1187400  26.670000
# 132 2011-01-05  26.48  26.900000  26.190001  26.830000  1446700  26.830000
# 133 2011-01-06  26.83  28.000000  26.809999  27.879999  2061200  27.879999
# 134 2011-01-07  28.00  28.580000  27.900000  28.240000  2247900  28.240000
#
#      Year Month Day
# 130  2011     1   3
# 131  2011     1   4
# 132  2011     1   5
# 133  2011     1   6
# 134  2011     1   7

# %%
df.shape
# Out:
# (1510, 10)

# %%
#drop raw
1692-1510
# Out:
# 182

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1510.000000  1510.000000  1510.000000  1510.000000  1.510000e+03
# mean    137.765510   140.194609   135.185550   137.726589  4.466171e+06
# std      91.784958    93.148252    90.305671    91.749316  4.381167e+06
# min      21.780001    22.270000    21.110001    21.830000  2.396000e+05
# 25%      31.804999    32.335001    31.002500    31.792500  1.309225e+06
# 50%     172.584999   177.534996   167.974998   173.229996  3.370550e+06
# 75%     220.114994   223.374996   216.780002   219.602501  5.865400e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1510.000000
# mean    137.726589
# std      91.749316
# min      21.830000
# 25%      31.792500
# 50%     173.229996
# 75%     219.602501
# max     286.040009

# %%
gb_year=df.groupby("Year")


df_2011=gb_year.get_group('2011')
df_2012=gb_year.get_group('2012')
df_2013=gb_year.get_group('2013')
df_2014=gb_year.get_group('2014')
df_2015=gb_year.get_group('2015')
df_2016=gb_year.get_group('2016')

# %%
#plotting the data
plt.figure(figsize=(12,7))
plt.title('Close Price History',fontsize=20)
plt.plot(df['Date'],df['Close'], color='r')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Close Price USD', fontsize = 16)
plt.grid(True)
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#plotting the data
plt.figure(figsize=(12,7))
plt.title('Stock volume of tesla',fontsize=20)
plt.plot(df['Date'],df['Volume'], color='g')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Volume', fontsize = 16)
plt.show()

# %% [markdown]
# # Mean value of closing time  value of  each year's month

# %%
#year-2011
mean_2011_1=df_2011[df_2011['Month']=='1'] ['Close'].mean()
mean_2011_2=df_2011[df_2011['Month']=='2'] ['Close'].mean()
mean_2011_3=df_2011[df_2011['Month']=='3'] ['Close'].mean()
mean_2011_4=df_2011[df_2011['Month']=='4'] ['Close'].mean()
mean_2011_5=df_2011[df_2011['Month']=='5'] ['Close'].mean()
mean_2011_6=df_2011[df_2011['Month']=='6'] ['Close'].mean()
mean_2011_7=df_2011[df_2011['Month']=='7'] ['Close'].mean()
mean_2011_8=df_2011[df_2011['Month']=='8'] ['Close'].mean()
mean_2011_9=df_2011[df_2011['Month']=='9'] ['Close'].mean()
mean_2011_10=df_2011[df_2011['Month']=='10'] ['Close'].mean()
mean_2011_11=df_2011[df_2011['Month']=='11'] ['Close'].mean()
mean_2011_12=df_2011[df_2011['Month']=='12'] ['Close'].mean()


#year-2012
mean_2012_1=df_2012[df_2012['Month']=='1'] ['Close'].mean()
mean_2012_2=df_2012[df_2012['Month']=='2'] ['Close'].mean()
mean_2012_3=df_2012[df_2012['Month']=='3'] ['Close'].mean()
mean_2012_4=df_2012[df_2012['Month']=='4'] ['Close'].mean()
mean_2012_5=df_2012[df_2012['Month']=='5'] ['Close'].mean()
mean_2012_6=df_2012[df_2012['Month']=='6'] ['Close'].mean()
mean_2012_7=df_2012[df_2012['Month']=='7'] ['Close'].mean()
mean_2012_8=df_2012[df_2012['Month']=='8'] ['Close'].mean()
mean_2012_9=df_2012[df_2012['Month']=='9'] ['Close'].mean()
mean_2012_10=df_2012[df_2012['Month']=='10'] ['Close'].mean()
mean_2012_11=df_2012[df_2012['Month']=='11'] ['Close'].mean()
mean_2012_12=df_2012[df_2012['Month']=='12'] ['Close'].mean()


#year-2013
mean_2013_1=df_2013[df_2013['Month']=='1'] ['Close'].mean()
mean_2013_2=df_2013[df_2013['Month']=='2'] ['Close'].mean()
mean_2013_3=df_2013[df_2013['Month']=='3'] ['Close'].mean()
mean_2013_4=df_2013[df_2013['Month']=='4'] ['Close'].mean()
mean_2013_5=df_2013[df_2013['Month']=='5'] ['Close'].mean()
mean_2013_6=df_2013[df_2013['Month']=='6'] ['Close'].mean()
mean_2013_7=df_2013[df_2013['Month']=='7'] ['Close'].mean()
mean_2013_8=df_2013[df_2013['Month']=='8'] ['Close'].mean()
mean_2013_9=df_2013[df_2013['Month']=='9'] ['Close'].mean()
mean_2013_10=df_2013[df_2013['Month']=='10'] ['Close'].mean()
mean_2013_11=df_2013[df_2013['Month']=='11'] ['Close'].mean()
mean_2013_12=df_2013[df_2013['Month']=='12'] ['Close'].mean()


#year-2014
mean_2014_1=df_2014[df_2014['Month']=='1'] ['Close'].mean()
mean_2014_2=df_2014[df_2014['Month']=='2'] ['Close'].mean()
mean_2014_3=df_2014[df_2014['Month']=='3'] ['Close'].mean()
mean_2014_4=df_2014[df_2014['Month']=='4'] ['Close'].mean()
mean_2014_5=df_2014[df_2014['Month']=='5'] ['Close'].mean()
mean_2014_6=df_2014[df_2014['Month']=='6'] ['Close'].mean()
mean_2014_7=df_2014[df_2014['Month']=='7'] ['Close'].mean()
mean_2014_8=df_2014[df_2014['Month']=='8'] ['Close'].mean()
mean_2014_9=df_2014[df_2014['Month']=='9'] ['Close'].mean()
mean_2014_10=df_2014[df_2014['Month']=='10'] ['Close'].mean()
mean_2014_11=df_2014[df_2014['Month']=='11'] ['Close'].mean()
mean_2014_12=df_2014[df_2014['Month']=='12'] ['Close'].mean()


#year-2015
mean_2015_1=df_2015[df_2015['Month']=='1'] ['Close'].mean()
mean_2015_2=df_2015[df_2015['Month']=='2'] ['Close'].mean()
mean_2015_3=df_2015[df_2015['Month']=='3'] ['Close'].mean()
mean_2015_4=df_2015[df_2015['Month']=='4'] ['Close'].mean()
mean_2015_5=df_2015[df_2015['Month']=='5'] ['Close'].mean()
mean_2015_6=df_2015[df_2015['Month']=='6'] ['Close'].mean()
mean_2015_7=df_2015[df_2015['Month']=='7'] ['Close'].mean()
mean_2015_8=df_2015[df_2015['Month']=='8'] ['Close'].mean()
mean_2015_9=df_2015[df_2015['Month']=='9'] ['Close'].mean()
mean_2015_10=df_2015[df_2015['Month']=='10'] ['Close'].mean()
mean_2015_11=df_2015[df_2015['Month']=='11'] ['Close'].mean()
mean_2015_12=df_2015[df_2015['Month']=='12'] ['Close'].mean()


#year-2016
mean_2016_1=df_2016[df_2016['Month']=='1'] ['Close'].mean()
mean_2016_2=df_2016[df_2016['Month']=='2'] ['Close'].mean()
mean_2016_3=df_2016[df_2016['Month']=='3'] ['Close'].mean()
mean_2016_4=df_2016[df_2016['Month']=='4'] ['Close'].mean()
mean_2016_5=df_2016[df_2016['Month']=='4'] ['Close'].mean()
mean_2016_6=df_2016[df_2016['Month']=='6'] ['Close'].mean()
mean_2016_7=df_2016[df_2016['Month']=='7'] ['Close'].mean()
mean_2016_8=df_2016[df_2016['Month']=='8'] ['Close'].mean()
mean_2016_9=df_2016[df_2016['Month']=='9'] ['Close'].mean()
mean_2016_10=df_2016[df_2016['Month']=='10'] ['Close'].mean()
mean_2016_11=df_2016[df_2016['Month']=='11'] ['Close'].mean()
mean_2016_12=df_2016[df_2016['Month']=='12'] ['Close'].mean()

# %%
month=range(1,13)

mean_2011=(mean_2011_1,mean_2011_2,mean_2011_3,mean_2011_4,mean_2011_5,mean_2011_6,mean_2011_7,mean_2011_8,mean_2011_9,mean_2011_10,mean_2011_11,mean_2011_12)
mean_2012=(mean_2012_1,mean_2012_2,mean_2012_3,mean_2012_4,mean_2012_5,mean_2012_6,mean_2012_7,mean_2012_8,mean_2012_9,mean_2012_10,mean_2012_11,mean_2012_12)
mean_2013=(mean_2013_1,mean_2013_2,mean_2013_3,mean_2013_4,mean_2013_5,mean_2013_6,mean_2013_7,mean_2013_8,mean_2013_9,mean_2013_10,mean_2013_11,mean_2013_12)
mean_2014=(mean_2014_1,mean_2014_2,mean_2014_3,mean_2014_4,mean_2014_5,mean_2014_6,mean_2014_7,mean_2014_8,mean_2014_9,mean_2014_10,mean_2014_11,mean_2014_12)
mean_2015=(mean_2015_1,mean_2015_2,mean_2015_3,mean_2015_4,mean_2015_5,mean_2015_6,mean_2015_7,mean_2015_8,mean_2015_9,mean_2015_10,mean_2015_11,mean_2015_12)
mean_2016=(mean_2016_1,mean_2016_2,mean_2016_3,mean_2016_4,mean_2016_5,mean_2016_6,mean_2016_7,mean_2016_8,mean_2016_9,mean_2016_10,mean_2016_11,mean_2016_12)

plt.figure(figsize=(12,7))
plt.style.use("seaborn-ticks")
plt.title('2011-16 closing mean value of Tesla share price',fontsize='25')
plt.plot(month,mean_2011,label=2011,color='r',marker='o')
plt.plot(month,mean_2012,label=2012,color='b',marker='o')
plt.plot(month,mean_2013,label=2013,color='y',marker='o')
plt.plot(month,mean_2014,label=2014,color='g',marker='o')
plt.plot(month,mean_2015,label=2015,color='m',marker='o')
plt.plot(month,mean_2016,label=2016,color='k',marker='o')



plt.xlabel("Month",fontsize='15')
plt.ylabel("Closing Price USD",fontsize='15')
plt.grid(True)
plt.xticks(range(1,13))
plt.legend(loc='upper left')


plt.show()

# %%
mean_2015_7>mean_2014_9

#July,2015 is the  avreage max closing  month
# Out:
# True

# %%
df_2011_1=df_2011[df_2011['Month']=='1']

# %%
x=df_2011_1['Day']
y=df_2011_1['Open']
z=df_2011_1['Close']
plt.figure(figsize=(10,7))
plt.style.use('seaborn-darkgrid')
plt.title('Open and Close Value of Tesla January,2011',fontsize='18')
plt.plot(x,y,label="opening value",color='b',marker='o')
plt.plot(x,z,label="closing value",color='r',marker='o')
plt.xlabel('Day',fontsize='14')
plt.ylabel('Price USD',fontsize='14')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# # Max open  and Close value of Tesla Share

# %%
df['Open'].max()
# Out:
# 287.670013

# %%
df[df['Open']==287.670013] #max open
# Out:
#            Date        Open   High         Low       Close   Volume  \
# 1052 2014-09-03  287.670013  288.0  280.100006  281.190002  6772300
#
#        Adj Close  Year Month Day
# 1052  281.190002  2014     9   3

# %%
df['Close'].max()
# Out:
# 286.040009

# %%
df[df['Close']==286.040009] #max close
# Out:
#            Date       Open        High         Low       Close   Volume  \
# 1053 2014-09-04  284.01001  291.420013  280.399994  286.040009  8341700
#
#        Adj Close  Year Month Day
# 1053  286.040009  2014     9   4

# %%
df_2014_9=df_2014[df["Month"]=='9']



x=df_2014_9['Day']
y=df_2014_9['Open']
z=df_2014_9['Close']
plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Max Open and Close Month of Tesla Share Value.September,2014',fontsize='20')
plt.plot(x,y,label="opening value",color='b',marker='o')
plt.plot(x,z,label="closing value",color='r',marker='o')
plt.xlabel("Day",fontsize='15')
plt.ylabel('USD Dollar$',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Min Open and Close  Value of Tesla Share

# %%
df['Open'].min()
# Out:
# 21.780001000000002

# %%
df[df['Open']==21.780001000000002]
# Out:
#           Date       Open   High   Low      Close   Volume  Adj Close  Year  \
# 166 2011-02-24  21.780001  22.58  21.5  22.530001  1055300  22.530001  2011
#
#     Month Day
# 166     2  24

# %%
df['Close'].min()
# Out:
# 21.83

# %%
df[df['Close']==21.83]
# Out:
#           Date   Open  High        Low  Close   Volume  Adj Close  Year Month  \
# 165 2011-02-23  22.18  22.5  21.110001  21.83  1605600      21.83  2011     2
#
#     Day
# 165  23

# %%
df_2011_2=df_2011[df["Month"]=='2']



x=df_2011_2['Day']
y=df_2011_2['Open']
z=df_2011_2['Close']
plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Min Open and Close Month of tesla Share.February,2011',fontsize='20')
plt.plot(x,y,label="opening value",color='b',marker='o')
plt.plot(x,z,label="closing value",color='r',marker='o')
plt.xlabel("Day",fontsize='15')
plt.ylabel('USD Dollar$',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Max Volume

# %%
df['Volume'].max()
# Out:
# 37163900

# %%
df[df['Volume']==37163900]
# Out:
#           Date       Open       High        Low      Close    Volume  \
# 723 2013-05-14  94.220001  97.120003  81.150002  83.239998  37163900
#
#      Adj Close  Year Month Day
# 723  83.239998  2013     5  14

# %%
df_2013_5=df_2013[df["Month"]=='5']
df_2013_5
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           Date        Open        High         Low       Close    Volume  \
# 714 2013-05-01   55.990002   55.990002   53.000000   53.279999   2742800
# 715 2013-05-02   53.849998   55.270000   53.700001   54.110001   3050400
# 716 2013-05-03   56.470001   56.470001   54.500000   54.549999   3378700
# 717 2013-05-06   56.389999   59.660000   55.500000   59.500000   4366700
# 718 2013-05-07   62.000000   62.369999   55.119999   55.509998   9991000
# 719 2013-05-08   57.500000   58.200001   55.709999   55.790001   6769900
# 720 2013-05-09   70.120003   75.769997   63.689999   69.400002  28605000
# 721 2013-05-10   69.650002   81.000000   69.250000   76.760002  25082600
# 722 2013-05-13   80.989998   88.000000   79.150002   87.800003  22416900
# ...

# %%
x=df_2013_5['Day']
y=df_2013_5['Volume']
plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Max Volume  Month of Tesla Share Value.May,2013',fontsize='20')

plt.plot(x,y,label="Volume",color='g',marker='o')

plt.xlabel("Day",fontsize='15')
plt.ylabel('Volume',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Min Volume

# %%
df['Volume'].min()
# Out:
# 239600

# %%
df[df['Volume']==239600]
# Out:
#           Date       Open   High    Low  Close  Volume  Adj Close  Year Month  \
# 357 2011-11-25  31.549999  32.41  31.08  31.66  239600      31.66  2011    11
#
#     Day
# 357  25

# %%
df_2011_11=df_2011[df_2011['Month']=='11']
df_2011_11
# Out:
#           Date       Open       High        Low      Close   Volume  \
# 340 2011-11-01  28.389999  28.920000  28.000000  28.879999   635200
# 341 2011-11-02  29.000000  29.260000  28.250000  28.709999   875300
# 342 2011-11-03  30.000000  32.490002  29.530001  32.459999  2509700
# 343 2011-11-04  31.459999  32.400002  30.510000  32.310001  3032900
# 344 2011-11-07  31.639999  32.000000  30.750000  31.270000  1266300
# 345 2011-11-08  31.370001  32.000000  30.719999  31.840000  1167900
# 346 2011-11-09  30.870001  31.490000  30.299999  30.879999   953700
# 347 2011-11-10  30.940001  31.500000  30.650000  31.330000   747300
# 348 2011-11-11  31.900000  34.500000  30.570000  33.639999  3868300
# 349 2011-11-14  33.000000  33.540001  32.619999  33.220001  1325700
# 350 2011-11-15  32.919998  34.400002  32.730000  33.930000   891000
# 351 2011-11-16  33.480000  35.000000  33.400002  34.939999  1833200
# 352 2011-11-17  34.500000  34.900002  33.189999  33.680000  1349300
# ...

# %%
x=df_2011_11['Day']
y=df_2011_11['Volume']

plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Min Volume  Month of Tesla Share Value, November,2011',fontsize='20')

plt.plot(x,y,label="Volume",color='g',marker='o')
plt.xlabel("Day",fontsize='15')
plt.ylabel('Volume',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # If needed to be searched by date

# %%
df[df['Date'].between('2011-01-05','2013-02-10')]
# Out:
#           Date       Open       High        Low      Close   Volume  \
# 132 2011-01-05  26.480000  26.900000  26.190001  26.830000  1446700
# 133 2011-01-06  26.830000  28.000000  26.809999  27.879999  2061200
# 134 2011-01-07  28.000000  28.580000  27.900000  28.240000  2247900
# 135 2011-01-10  28.170000  28.680000  28.049999  28.450001  1342700
# 136 2011-01-11  28.590000  28.709999  26.920000  26.959999  1710200
# ..         ...        ...        ...        ...        ...      ...
# 654 2013-02-04  38.400002  38.419998  37.590000  37.740002  1128000
# 655 2013-02-05  38.000000  38.650002  37.680000  38.130001  1310200
# 656 2013-02-06  38.180000  39.389999  37.900002  39.169998  1893200
# 657 2013-02-07  39.189999  39.680000  38.950001  39.480000  1196600
# 658 2013-02-08  39.450001  40.000000  39.139999  39.240002  1139800
#
#      Adj Close  Year Month Day
# 132  26.830000  2011     1   5
# 133  27.879999  2011     1   6
# 134  28.240000  2011     1   7
# ...

# %% [markdown]
# # Search by loc

# %%
df.loc[149:346]
# Out:
#           Date       Open       High        Low      Close   Volume  \
# 149 2011-01-31  24.049999  24.120001  23.500000  24.100000   830300
# 150 2011-02-01  24.309999  24.730000  23.540001  23.910000   707800
# 151 2011-02-02  24.160000  24.180000  23.670000  23.940001   569500
# 152 2011-02-03  23.820000  23.900000  23.150000  23.629999   512000
# 153 2011-02-04  23.440001  23.670000  23.219999  23.459999   544000
# ..         ...        ...        ...        ...        ...      ...
# 342 2011-11-03  30.000000  32.490002  29.530001  32.459999  2509700
# 343 2011-11-04  31.459999  32.400002  30.510000  32.310001  3032900
# 344 2011-11-07  31.639999  32.000000  30.750000  31.270000  1266300
# 345 2011-11-08  31.370001  32.000000  30.719999  31.840000  1167900
# 346 2011-11-09  30.870001  31.490000  30.299999  30.879999   953700
#
#      Adj Close  Year Month Day
# 149  24.100000  2011     1  31
# 150  23.910000  2011     2   1
# 151  23.940001  2011     2   2
# ...

# %%
profit_days=df[df["Open"]<df['Close']].count()
loss_days=df[df["Open"]>df['Close']].count()

# %%
profit_days
# Out:
# Date         737
# Open         737
# High         737
# Low          737
# Close        737
# Volume       737
# Adj Close    737
# Year         737
# Month        737
# Day          737
# dtype: int64

# %%
loss_days
# Out:
# Date         769
# Open         769
# High         769
# Low          769
# Close        769
# Volume       769
# Adj Close    769
# Year         769
# Month        769
# Day          769
# dtype: int64

# %%
737+769
# Out:
# 1506

# %%
unchanged_days=df[df["Open"]==df['Close']].count()

# %%
unchanged_days
# Out:
# Date         4
# Open         4
# High         4
# Low          4
# Close        4
# Volume       4
# Adj Close    4
# Year         4
# Month        4
# Day          4
# dtype: int64
